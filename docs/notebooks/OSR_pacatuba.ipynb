# %%
# ==============================================================================
# 1. IMPORTAÇÕES E LOGGER PARA PARALELISMO
# ==============================================================================

import os
import time
import logging
import threading
from typing import List
import pandas as pd
import csv
import unicodedata
import re
from concurrent.futures import ThreadPoolExecutor, as_completed

import numpy # Usado para dividir a lista de tarefas
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException

from webdriver_manager.chrome import ChromeDriverManager

# Objeto de armazenamento de dados que é local (privado) para cada thread
log_context = threading.local()

class TaskIdFilter(logging.Filter):
    """Filtro para adicionar um ID de tarefa/thread aos registros de log."""
    def filter(self, record: logging.LogRecord) -> bool:
        record.task_id = getattr(log_context, 'task_id', 'MainThread')
        return True

def setup_logging(log_file: str) -> logging.Logger:
    os.makedirs(os.path.dirname(log_file), exist_ok=True)
    logger = logging.getLogger('osr_pacatuba')
    logger.setLevel(logging.INFO)

    if logger.hasHandlers():
        logger.handlers.clear()

    formatter = logging.Formatter("[%(task_id)s] - %(asctime)s - %(levelname)s - [%(funcName)s] - %(message)s")
    task_filter = TaskIdFilter()

    file_handler = logging.FileHandler(log_file, mode='w', encoding='utf-8')
    file_handler.setFormatter(formatter)
    file_handler.addFilter(task_filter)

    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    console_handler.addFilter(task_filter)

    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    # Reduz o ruído de bibliotecas externas
    logging.getLogger('selenium').setLevel(logging.WARNING)
    logging.getLogger('urllib3').setLevel(logging.WARNING)
    logging.getLogger('WDM').setLevel(logging.WARNING)

    return logger

# A variável logger será inicializada dentro da função de orquestração
logger = None

# %%
# ==============================================================================
# 2. CONSTANTES E FUNÇÕES AUXILIARES
# ==============================================================================

# Agora os termos são os códigos, conforme seu código
TERMOS_ROYALTIES = ["royaltie", "royalty", "petroleo"]

RE_REMOVE_PUNCTUATION = re.compile(r'[^a-zA-Z0-9\s]')

def normalizar(texto: str) -> str:
    """
    Normaliza um texto removendo acentos, pontuações e convertendo para minúsculas.
    """
    if not isinstance(texto, str):
        return ""
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = RE_REMOVE_PUNCTUATION.sub('', texto)
    return texto.lower()

# %%
# ==============================================================================
# 3. DRIVER E INTERAÇÕES COM A PÁGINA (start_driver ATUALIZADO)
# ==============================================================================

def start_driver(headless=False) -> webdriver.Chrome:
    logger.info("Iniciando e configurando instância do Chrome...")
    options = webdriver.ChromeOptions()

    if headless:
        options.add_argument("--headless=new")
        options.add_argument("--disable-gpu")
        options.add_argument("--no-sandbox")
    else:
        options.add_argument('--window-size=1920,1080')
        options.add_argument("--disable-blink-features=AutomationControlled")
        options.add_experimental_option("excludeSwitches", ["enable-automation"])
    
    # A função agora apenas cria e retorna o driver, sem navegar.
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    return driver


def selecionar_dropdown(driver, container_id, texto):
    try:
        logger.info(f"Selecionando: {texto}")
        trigger = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//span[@aria-labelledby='{container_id}']"))
        )
        trigger.click()
        opcao = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//li[contains(@class, 'select2-results__option') and normalize-space(.)='{texto}']"))
        )
        opcao.click()
    except Exception as e:
        logger.error(f"Erro ao selecionar {texto} no campo {container_id}: {e}")
        raise

def ir_para_proxima_pagina(driver):
    try:
        proxima_pagina_locator = (By.XPATH, "//a[contains(@class, 'page-link')][i[contains(@class, 'next')]]")
        botao = driver.find_element(*proxima_pagina_locator)
        parent_li = botao.find_element(By.XPATH, "./parent::li")
        
        if "disabled" in parent_li.get_attribute("class"):
            logger.info("Última página alcançada.")
            return False

        botao.click()
        logger.info("Navegando para a próxima página de resultados.")
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        return True
    except NoSuchElementException:
        logger.info("Botão 'Próxima Página' não encontrado. Fim da paginação.")
        return False

# %%
# ==============================================================================
# 4. WORKER PARALELO E ORQUESTRAÇÃO
# ==============================================================================
def worker_extrair_detalhes(links: List[str], ano_alvo: str) -> List[dict]:
    """
    Função 'worker' para threads. Otimizada para verificar a fonte de recurso
    primeiro, antes de extrair todos os outros dados.
    """
    log_context.task_id = f"Worker-{threading.get_ident() % 1000}"
    logger = logging.getLogger('osr_pacatuba')
    
    logger.info(f"Worker iniciado. Processando {len(links)} links.")
    
    dados_coletados_pela_thread = []
    driver = None
    try:
        driver = start_driver(headless=True)
        
        for i, link in enumerate(links):
            try:
                logger.debug(f"Acessando link {i+1}/{len(links)}.")
                driver.get(link)
                
                # Aguarda o elemento mais básico da página de detalhes para garantir o carregamento
                WebDriverWait(driver, 20).until(
                    EC.visibility_of_element_located((By.ID, "table-dados"))
                )

                # Mapa de XPaths para todos os campos na página de detalhes.
                XPATHS_DETALHES = {           
                    'empenho':          '//*[@id="table-dados"]/tbody/tr[2]/td[1]',
                    'credor':           '//*[@id="table-dados"]/tbody/tr[2]/td[2]',
                    'data_nota':        '//*[@id="table-dados"]/tbody/tr[2]/td[3]',

                    'processo':         '//*[@id="table-dados"]/tbody/tr[4]/th[1]',
                    'fonte_recurso':    '//*[@id="table-dados"]/tbody/tr[4]/th[2]',            
                    'numero_documento': '//*[@id="table-dados"]/tbody/tr[4]/th[3]',

                    'valor_pago':       '//*[@id="table-dados"]/tbody/tr[6]/td[1]',
                    'valor_retido':     '//*[@id="table-dados"]/tbody/tr[6]/td[2]',
                    'forma_pagamento':  '//*[@id="table-dados"]/tbody/tr[6]/td[3]',
                    
                    'historico':        '//*[@id="table-historico"]/tbody/tr/td',
                    'relacionado_covid':'//*[@id="table-outras-informacoes"]/tbody/tr/td[1]',
                    'relacionado_LC173':'//*[@id="table-outras-informacoes"]/tbody/tr/td[2]'
                }
                
                # --- ETAPA 1: Extrair APENAS a Fonte de Recurso para verificação ---
                logger.debug("Verificando a Fonte de Recurso primeiro...")
                fonte_recurso_texto = None
                try:
                    # Usa o XPath específico para a fonte de recurso
                    fonte_recurso_element = driver.find_element(By.XPATH, XPATHS_DETALHES['fonte_recurso'])
                    fonte_recurso_texto = fonte_recurso_element.text.strip()
                    fonte_recurso_texto = normalizar(fonte_recurso_texto)
                    
                except NoSuchElementException:
                    logger.warning(f"Campo 'fonte_recurso' não encontrado no link {link}. Pulando.")
                    continue # Pula para o próximo link

                # --- ETAPA 2: Verificar se é de royalties ANTES de extrair o resto ---
                if fonte_recurso_texto and any(termo in fonte_recurso_texto for termo in TERMOS_ROYALTIES):
                    logger.info(f"Royalties encontrados (Fonte: '{fonte_recurso_texto}'). Extraindo todos os dados do link: {link}")
                    
                    # --- ETAPA 3: Se for royalties, extrair todos os outros campos ---
                    dados_completos = {'fonte_recurso': fonte_recurso_texto}
                    
                    for nome_campo, xpath in XPATHS_DETALHES.items():
                        if nome_campo == 'fonte_recurso': # Já pegamos este
                            continue
                        try:
                            dados_completos[nome_campo] = driver.find_element(By.XPATH, xpath).text.strip()
                        except NoSuchElementException:
                            dados_completos[nome_campo] = None
                    
                    dados_completos['link_detalhe'] = link
                    dados_coletados_pela_thread.append(dados_completos)

                else:
                    logger.debug(f"Link não é de royalties. Fonte: '{fonte_recurso_texto}'. Pulando extração detalhada.")

            except Exception as e_link:
                logger.error(f"Erro ao processar o link {link}: {e_link}")
                continue # Continua para o próximo link
    finally:
        if driver: 
            driver.quit()
        logger.info("Worker finalizado.")
    
    return dados_coletados_pela_thread


def processar_ano_em_paralelo(ano_alvo: str, max_workers: int = 4):
    """
    Orquestra o processo: coleta todos os links e depois distribui a extração.
    """
    global logger
    logger = setup_logging(log_file=f"../logs/pacatuba/extracao_{ano_alvo}.log")
    
    logger.info(f"--- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE {ano_alvo} ---")
    
    # --- FASE 1: COLETA DE TODOS OS LINKS NA THREAD PRINCIPAL ---
    links_para_processar = []
    driver = None
    try:
        logger.info("Fase 1: Coletando todos os links de detalhes...")
        driver = start_driver(headless=True)
        url_incial = "https://transparencia.pacatuba.se.gov.br/public/portal/despesas"
        driver.get(url_incial)
        WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.TAG_NAME, 'body')))
        
        selecionar_dropdown(driver, "select2-tipo-container", "Pagamento")
        selecionar_dropdown(driver, "select2-ano-container", ano_alvo)
        
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button#filtrar.btn-buscar"))).click()
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        
        pagina_atual = 1
        while True:
            logger.info(f"Coletando links da página de resultados: {pagina_atual}")
            
            # =================================================================
            # AQUI ESTÁ A CORREÇÃO
            # =================================================================
            # Usando o seletor XPath específico para a coluna de detalhes
            botoes_detalhes_locator = (By.XPATH, "//td[@serigyitem='detalhesPagamento']/a")
            botoes_detalhes = WebDriverWait(driver, 10).until(
                EC.presence_of_all_elements_located(botoes_detalhes_locator)
            )
            # =================================================================
            
            for botao in botoes_detalhes:
                if link := botao.get_attribute('href'): 
                    links_para_processar.append(link)
            #break
            if not ir_para_proxima_pagina(driver): 
                break
            pagina_atual += 1
            
    finally:
        if driver: 
            driver.quit()
    
    logger.info(f"Fase 1 concluída. Total de {len(links_para_processar)} links de detalhes coletados.")
    
    if not links_para_processar: 
        logger.warning("Nenhum link para processar. Encerrando.")
        return

    # --- FASE 2: DISTRIBUIÇÃO E PROCESSAMENTO PARALELO ---
    # (Esta parte do código permanece a mesma, pois o erro estava na coleta dos links)
    logger.info(f"Fase 2: Iniciando extração com {max_workers} workers.")
    dados_finais = []
    
    if max_workers > len(links_para_processar): max_workers = len(links_para_processar)
    
    lista_de_tarefas = numpy.array_split(links_para_processar, max_workers) if max_workers > 0 else [links_para_processar]
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(worker_extrair_detalhes, tarefa.tolist(), ano_alvo): i for i, tarefa in enumerate(lista_de_tarefas) if tarefa.size > 0}
        
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"Processando Detalhes de {ano_alvo}"):
            if resultado_parcial := future.result(): 
                dados_finais.extend(resultado_parcial)

    # --- SALVAR RESULTADOS ---
    if dados_finais:
        output_dir = os.path.join("dados_finais", "pacatuba")
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, f"royalties_pacatuba_{ano_alvo}.csv")
        
        df = pd.DataFrame(dados_finais)
        df.to_csv(output_path, index=False, sep=';', encoding='utf-8-sig')
        logger.info(f"Processamento concluído. {len(df)} registros salvos em: {output_path}")
    else:
        logger.info("Nenhum registro de royalties foi extraído.")
        
    logger.info(f"--- FINALIZADO PROCESSAMENTO DE {ano_alvo} ---")

# %%
# ==============================================================================
# 5. EXECUÇÃO DO SCRIPT
# ==============================================================================

if __name__ == "__main__":
    ANO_A_PROCESSAR = "2018"
    NUMERO_DE_THREADS = 2 # Defina quantos navegadores rodarão em paralelo

    processar_ano_em_paralelo(
        ano_alvo=ANO_A_PROCESSAR,
        max_workers=NUMERO_DE_THREADS
    )
# Out:
# [MainThread] - 2025-07-14 12:08:35,924 - INFO - [processar_ano_em_paralelo] - --- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE 2018 ---
# [MainThread] - 2025-07-14 12:08:35,926 - INFO - [processar_ano_em_paralelo] - Fase 1: Coletando todos os links de detalhes...
# [MainThread] - 2025-07-14 12:08:35,927 - INFO - [start_driver] - Iniciando e configurando instância do Chrome...
# [MainThread] - 2025-07-14 12:08:52,043 - INFO - [selecionar_dropdown] - Selecionando: Pagamento
# [MainThread] - 2025-07-14 12:08:52,264 - INFO - [selecionar_dropdown] - Selecionando: 2018
# [MainThread] - 2025-07-14 12:09:03,924 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 1
# [MainThread] - 2025-07-14 12:09:15,587 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:09:15,610 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 2
# [MainThread] - 2025-07-14 12:09:28,046 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:09:28,064 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 3
# [MainThread] - 2025-07-14 12:09:40,860 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:09:40,890 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 4
# [MainThread] - 2025-07-14 12:09:52,604 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:09:52,628 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 5
# [MainThread] - 2025-07-14 12:10:04,244 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:10:04,264 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 6
# [MainThread] - 2025-07-14 12:10:15,849 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:10:15,874 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 7
# [MainThread] - 2025-07-14 12:10:27,424 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:10:27,444 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 8
# [MainThread] - 2025-07-14 12:10:39,092 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:10:39,113 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 9
# [MainThread] - 2025-07-14 12:10:50,719 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:10:50,740 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 10
# [MainThread] - 2025-07-14 12:11:02,369 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:11:02,388 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 11
# [MainThread] - 2025-07-14 12:11:13,882 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:11:13,905 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 12
# [MainThread] - 2025-07-14 12:11:25,487 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:11:25,506 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 13
# [MainThread] - 2025-07-14 12:11:37,016 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:11:37,037 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 14
# [MainThread] - 2025-07-14 12:11:48,654 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:11:48,675 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 15
# [MainThread] - 2025-07-14 12:12:00,221 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:00,242 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 16
# [MainThread] - 2025-07-14 12:12:11,733 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:11,754 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 17
# [MainThread] - 2025-07-14 12:12:23,317 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:23,337 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 18
# [MainThread] - 2025-07-14 12:12:34,910 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:34,932 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 19
# [MainThread] - 2025-07-14 12:12:46,632 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:46,654 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 20
# [MainThread] - 2025-07-14 12:12:58,199 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:12:58,219 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 21
# [MainThread] - 2025-07-14 12:13:09,709 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:13:09,729 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 22
# [MainThread] - 2025-07-14 12:13:23,506 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:13:23,527 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 23
# [MainThread] - 2025-07-14 12:13:35,039 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:13:35,060 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 24
# [MainThread] - 2025-07-14 12:13:46,581 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:13:46,601 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 25
# [MainThread] - 2025-07-14 12:13:58,784 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:13:58,804 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 26
# [MainThread] - 2025-07-14 12:14:10,380 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:14:10,399 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 27
# [MainThread] - 2025-07-14 12:14:21,999 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:14:22,021 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 28
# [MainThread] - 2025-07-14 12:14:33,564 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:14:33,587 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 29
# [MainThread] - 2025-07-14 12:14:50,117 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:14:50,138 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 30
# [MainThread] - 2025-07-14 12:15:02,865 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:15:02,886 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 31
# [MainThread] - 2025-07-14 12:15:14,386 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:15:14,405 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 32
# [MainThread] - 2025-07-14 12:15:25,906 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:15:25,926 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 33
# [MainThread] - 2025-07-14 12:15:37,479 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:15:37,498 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 34
# [MainThread] - 2025-07-14 12:15:49,084 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:15:49,105 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 35
# [MainThread] - 2025-07-14 12:16:00,659 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:16:00,682 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 36
# [MainThread] - 2025-07-14 12:16:12,169 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:16:12,190 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 37
# [MainThread] - 2025-07-14 12:16:23,731 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:16:23,753 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 38
# [MainThread] - 2025-07-14 12:16:35,339 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:16:35,362 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 39
# [MainThread] - 2025-07-14 12:16:55,047 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:16:55,068 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 40
# [MainThread] - 2025-07-14 12:17:06,986 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:17:07,003 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 41
# [MainThread] - 2025-07-14 12:17:18,536 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:17:18,557 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 42
# [MainThread] - 2025-07-14 12:17:30,106 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:17:30,126 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 43
# [MainThread] - 2025-07-14 12:17:41,750 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:17:41,772 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 44
# [MainThread] - 2025-07-14 12:17:53,247 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:17:53,265 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 45
# [MainThread] - 2025-07-14 12:18:04,779 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:18:04,797 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 46
# [MainThread] - 2025-07-14 12:18:16,310 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:18:16,332 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 47
# [MainThread] - 2025-07-14 12:18:27,940 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:18:27,960 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 48
# [MainThread] - 2025-07-14 12:18:39,695 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:18:39,716 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 49
# [MainThread] - 2025-07-14 12:18:51,316 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:18:51,340 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 50
# [MainThread] - 2025-07-14 12:19:02,857 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:19:02,875 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 51
# [MainThread] - 2025-07-14 12:19:14,567 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:19:14,586 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 52
# [MainThread] - 2025-07-14 12:19:26,133 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:19:26,153 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 53
# [MainThread] - 2025-07-14 12:19:37,874 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:19:37,894 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 54
# [MainThread] - 2025-07-14 12:19:49,422 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:19:49,444 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 55
# [MainThread] - 2025-07-14 12:19:59,903 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[16], line 9
#       6 ANO_A_PROCESSAR = "2018"
#       7 NUMERO_DE_THREADS = 2 # Defina quantos navegadores rodarão em paralelo
# ----> 9 processar_ano_em_paralelo(
#      10     ano_alvo=ANO_A_PROCESSAR,
#      11     max_workers=NUMERO_DE_THREADS
#      12 )
#
# Cell In[15], line 136, in processar_ano_em_paralelo(ano_alvo, max_workers)
#     134         links_para_processar.append(link)
#     135 #break
# --> 136 if not ir_para_proxima_pagina(driver):
#     137     break
#     138 pagina_atual += 1
#
# Cell In[14], line 50, in ir_para_proxima_pagina(driver)
#      48     botao.click()
#      49     logger.info("Navegando para a próxima página de resultados.")
# ---> 50     WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
#      51     return True
#      52 except NoSuchElementException:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\support\wait.py:138, in WebDriverWait.until(self, method, message)
#     136         break
#     137     time.sleep(self._poll)
# --> 138 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0x9e44a3+62419]
# 	GetHandleVerifier [0x0x9e44e4+62484]
# 	(No symbol) [0x0x822133]
# 	(No symbol) [0x0x86a8fe]
# 	(No symbol) [0x0x86ac9b]
# 	(No symbol) [0x0x8b3052]
# 	(No symbol) [0x0x88f4b4]
# 	(No symbol) [0x0x8b087a]
# 	(No symbol) [0x0x88f266]
# 	(No symbol) [0x0x85e852]
# 	(No symbol) [0x0x85f6f4]
# 	GetHandleVerifier [0x0xc54793+2619075]
# 	GetHandleVerifier [0x0xc4fbaa+2599642]
# 	GetHandleVerifier [0x0xa0b04a+221050]
# 	GetHandleVerifier [0x0x9fb2c8+156152]
# 	GetHandleVerifier [0x0xa01c7d+183213]
# 	GetHandleVerifier [0x0x9ec388+94904]
# 	GetHandleVerifier [0x0x9ec512+95298]
# 	GetHandleVerifier [0x0x9d766a+9626]
# 	BaseThreadInitThunk [0x0x762b7ba9+25]
# 	RtlInitializeExceptionChain [0x0x7761c28b+107]
# 	RtlClearBits [0x0x7761c20f+191]
