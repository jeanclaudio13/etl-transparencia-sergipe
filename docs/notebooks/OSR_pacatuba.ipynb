# %%
# ==============================================================================
# 1. IMPORTAÇÕES E LOGGER PARA PARALELISMO
# ==============================================================================

import os
import time
import logging
import threading
from typing import List
import pandas as pd
import csv
import unicodedata
import re
from concurrent.futures import ThreadPoolExecutor, as_completed

import numpy # Usado para dividir a lista de tarefas
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException

from webdriver_manager.chrome import ChromeDriverManager

# Objeto de armazenamento de dados que é local (privado) para cada thread
log_context = threading.local()

class TaskIdFilter(logging.Filter):
    """Filtro para adicionar um ID de tarefa/thread aos registros de log."""
    def filter(self, record: logging.LogRecord) -> bool:
        record.task_id = getattr(log_context, 'task_id', 'MainThread')
        return True

def setup_logging(log_file: str) -> logging.Logger:
    os.makedirs(os.path.dirname(log_file), exist_ok=True)
    logger = logging.getLogger('osr_pacatuba')
    logger.setLevel(logging.INFO)

    if logger.hasHandlers():
        logger.handlers.clear()

    formatter = logging.Formatter("[%(task_id)s] - %(asctime)s - %(levelname)s - [%(funcName)s] - %(message)s")
    task_filter = TaskIdFilter()

    file_handler = logging.FileHandler(log_file, mode='w', encoding='utf-8')
    file_handler.setFormatter(formatter)
    file_handler.addFilter(task_filter)

    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    console_handler.addFilter(task_filter)

    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    # Reduz o ruído de bibliotecas externas
    logging.getLogger('selenium').setLevel(logging.WARNING)
    logging.getLogger('urllib3').setLevel(logging.WARNING)
    logging.getLogger('WDM').setLevel(logging.WARNING)

    return logger

# A variável logger será inicializada dentro da função de orquestração
logger = None

# %%
# ==============================================================================
# 2. CONSTANTES E FUNÇÕES AUXILIARES
# ==============================================================================

# Agora os termos são os códigos, conforme seu código
TERMOS_ROYALTIES = ["royaltie", "royalty", "petroleo"]

RE_REMOVE_PUNCTUATION = re.compile(r'[^a-zA-Z0-9\s]')

def normalizar(texto: str) -> str:
    """
    Normaliza um texto removendo acentos, pontuações e convertendo para minúsculas.
    """
    if not isinstance(texto, str):
        return ""
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = RE_REMOVE_PUNCTUATION.sub('', texto)
    return texto.lower()

# %%
# ==============================================================================
# 3. DRIVER E INTERAÇÕES COM A PÁGINA (start_driver ATUALIZADO)
# ==============================================================================

def start_driver(headless=False) -> webdriver.Chrome:
    logger.info("Iniciando e configurando instância do Chrome...")
    options = webdriver.ChromeOptions()

    if headless:
        options.add_argument("--headless=new")
        options.add_argument("--disable-gpu")
        options.add_argument("--no-sandbox")
    else:
        options.add_argument('--window-size=1920,1080')
        options.add_argument("--disable-blink-features=AutomationControlled")
        options.add_experimental_option("excludeSwitches", ["enable-automation"])
    
    # A função agora apenas cria e retorna o driver, sem navegar.
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    return driver


def selecionar_dropdown(driver, container_id, texto):
    try:
        logger.info(f"Selecionando: {texto}")
        trigger = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//span[@aria-labelledby='{container_id}']"))
        )
        trigger.click()
        opcao = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//li[contains(@class, 'select2-results__option') and normalize-space(.)='{texto}']"))
        )
        opcao.click()
    except Exception as e:
        logger.error(f"Erro ao selecionar {texto} no campo {container_id}: {e}")
        raise

def ir_para_proxima_pagina(driver):
    """
    Tenta clicar no botão 'Próxima Página'. Retorna True se conseguiu, False caso contrário.
    """
    logger = logging.getLogger('osr_project') # Padronizando o nome do logger
    try:
        proxima_pagina_locator = (By.XPATH, "//a[contains(@class, 'page-link')][i[contains(@class, 'next')]]")
        
        botao = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located(proxima_pagina_locator)
        )
        parent_li = botao.find_element(By.XPATH, "./parent::li")
        
        if "disabled" in parent_li.get_attribute("class"):
            logger.info("Última página alcançada.")
            return False

        # --- 
        logger.debug("Executando clique na próxima página via JavaScript.")
        driver.execute_script("arguments[0].click();", botao)
        
        logger.info("Navegando para a próxima página de resultados.")
        # Espera a tabela de resultados da nova página carregar
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        return True
        
    except (NoSuchElementException, TimeoutException):
        logger.info("Botão 'Próxima Página' não encontrado. Fim da paginação.")
        return False
    except Exception as e:
        logger.error(f"Erro inesperado ao tentar paginar: {e}")
        return False

# %%
# ==============================================================================
# 4. WORKER PARALELO E ORQUESTRAÇÃO
# ==============================================================================
def worker_extrair_detalhes(links: List[str], ano_alvo: str) -> List[dict]:
    """
    Função 'worker' para threads. Otimizada para verificar a fonte de recurso
    primeiro, antes de extrair todos os outros dados.
    """
    log_context.task_id = f"Worker-{threading.get_ident() % 1000}"
    logger = logging.getLogger('osr_pacatuba')
    
    logger.info(f"Worker iniciado. Processando {len(links)} links.")
    
    dados_coletados_pela_thread = []
    driver = None
    try:
        driver = start_driver(headless=True)
        
        for i, link in enumerate(links):
            try:
                logger.debug(f"Acessando link {i+1}/{len(links)}.")
                driver.get(link)
                
                # Aguarda o elemento mais básico da página de detalhes para garantir o carregamento
                WebDriverWait(driver, 20).until(
                    EC.visibility_of_element_located((By.ID, "table-dados"))
                )

                # Mapa de XPaths para todos os campos na página de detalhes.
                XPATHS_DETALHES = {           
                    'empenho':          '//*[@id="table-dados"]/tbody/tr[2]/td[1]',
                    'credor':           '//*[@id="table-dados"]/tbody/tr[2]/td[2]',
                    'data_nota':        '//*[@id="table-dados"]/tbody/tr[2]/td[3]',

                    'processo':         '//*[@id="table-dados"]/tbody/tr[4]/th[1]',
                    'fonte_recurso':    '//*[@id="table-dados"]/tbody/tr[4]/th[2]',            
                    'numero_documento': '//*[@id="table-dados"]/tbody/tr[4]/th[3]',

                    'valor_pago':       '//*[@id="table-dados"]/tbody/tr[6]/td[1]',
                    'valor_retido':     '//*[@id="table-dados"]/tbody/tr[6]/td[2]',
                    'forma_pagamento':  '//*[@id="table-dados"]/tbody/tr[6]/td[3]',
                    
                    'historico':        '//*[@id="table-historico"]/tbody/tr/td',
                    'relacionado_covid':'//*[@id="table-outras-informacoes"]/tbody/tr/td[1]',
                    'relacionado_LC173':'//*[@id="table-outras-informacoes"]/tbody/tr/td[2]'
                }
                
                # --- ETAPA 1: Extrair APENAS a Fonte de Recurso para verificação ---
                logger.debug("Verificando a Fonte de Recurso primeiro...")
                fonte_recurso_texto = None
                try:
                    # Usa o XPath específico para a fonte de recurso
                    fonte_recurso_element = driver.find_element(By.XPATH, XPATHS_DETALHES['fonte_recurso'])
                    fonte_recurso_texto = fonte_recurso_element.text.strip()
                    fonte_recurso_texto = normalizar(fonte_recurso_texto)
                    
                except NoSuchElementException:
                    logger.warning(f"Campo 'fonte_recurso' não encontrado no link {link}. Pulando.")
                    continue # Pula para o próximo link

                # --- ETAPA 2: Verificar se é de royalties ANTES de extrair o resto ---
                if fonte_recurso_texto and any(termo in fonte_recurso_texto for termo in TERMOS_ROYALTIES):
                    logger.info(f"Royalties encontrados (Fonte: '{fonte_recurso_texto}'). Extraindo todos os dados do link: {link}")
                    
                    # --- ETAPA 3: Se for royalties, extrair todos os outros campos ---
                    dados_completos = {'fonte_recurso': fonte_recurso_texto}
                    
                    for nome_campo, xpath in XPATHS_DETALHES.items():
                        if nome_campo == 'fonte_recurso': # Já pegamos este
                            continue
                        try:
                            dados_completos[nome_campo] = driver.find_element(By.XPATH, xpath).text.strip()
                        except NoSuchElementException:
                            dados_completos[nome_campo] = None
                    
                    dados_completos['link_detalhe'] = link
                    dados_coletados_pela_thread.append(dados_completos)

                else:
                    logger.debug(f"Link não é de royalties. Fonte: '{fonte_recurso_texto}'. Pulando extração detalhada.")

            except Exception as e_link:
                logger.error(f"Erro ao processar o link {link}: {e_link}")
                continue # Continua para o próximo link
    finally:
        if driver: 
            driver.quit()
        logger.info("Worker finalizado.")
    
    return dados_coletados_pela_thread


def processar_ano_em_paralelo(ano_alvo: str, max_workers: int = 4):
    """
    Orquestra o processo: coleta todos os links e depois distribui a extração.
    """
    global logger
    logger = setup_logging(log_file=f"../logs/pacatuba/extracao_{ano_alvo}.log")
    
    logger.info(f"--- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE {ano_alvo} ---")
    
    # --- FASE 1: COLETA DE TODOS OS LINKS NA THREAD PRINCIPAL ---
    links_para_processar = []
    driver = None
    try:
        logger.info("Fase 1: Coletando todos os links de detalhes...")
        driver = start_driver(headless=True)
        url_incial = "https://transparencia.pacatuba.se.gov.br/public/portal/despesas"
        driver.get(url_incial)
        WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.TAG_NAME, 'body')))
        
        selecionar_dropdown(driver, "select2-tipo-container", "Pagamento")
        selecionar_dropdown(driver, "select2-ano-container", ano_alvo)
        
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button#filtrar.btn-buscar"))).click()
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        
        pagina_atual = 1
        while True:
            logger.info(f"Coletando links da página de resultados: {pagina_atual}")
            
            # Usando o seletor XPath específico para a coluna de detalhes
            botoes_detalhes_locator = (By.XPATH, "//td[@serigyitem='detalhesPagamento']/a")
            botoes_detalhes = WebDriverWait(driver, 10).until(
                EC.presence_of_all_elements_located(botoes_detalhes_locator)
            )
            # =================================================================
            
            for botao in botoes_detalhes:
                if link := botao.get_attribute('href'): 
                    links_para_processar.append(link)
            #break
            if not ir_para_proxima_pagina(driver): 
                break
            pagina_atual += 1
            
    finally:
        if driver: 
            driver.quit()
    
    logger.info(f"Fase 1 concluída. Total de {len(links_para_processar)} links de detalhes coletados.")
    
    if not links_para_processar: 
        logger.warning("Nenhum link para processar. Encerrando.")
        return

    # --- FASE 2: DISTRIBUIÇÃO E PROCESSAMENTO PARALELO ---
    # (Esta parte do código permanece a mesma, pois o erro estava na coleta dos links)
    logger.info(f"Fase 2: Iniciando extração com {max_workers} workers.")
    dados_finais = []
    
    if max_workers > len(links_para_processar): max_workers = len(links_para_processar)
    
    lista_de_tarefas = numpy.array_split(links_para_processar, max_workers) if max_workers > 0 else [links_para_processar]
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(worker_extrair_detalhes, tarefa.tolist(), ano_alvo): i for i, tarefa in enumerate(lista_de_tarefas) if tarefa.size > 0}
        
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"Processando Detalhes de Pacatuba de {ano_alvo}"):
            if resultado_parcial := future.result(): 
                dados_finais.extend(resultado_parcial)

    # --- SALVAR RESULTADOS ---
    if dados_finais:
        output_dir = os.path.join("dados_finais", "pacatuba")
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, f"royalties_pacatuba_{ano_alvo}.csv")
        
        df = pd.DataFrame(dados_finais)
        df.to_csv(output_path, index=False, sep=';', encoding='utf-8-sig')
        logger.info(f"Processamento concluído. {len(df)} registros salvos em: {output_path}")
    else:
        logger.info("Nenhum registro de royalties foi extraído.")
        
    logger.info(f"--- FINALIZADO PROCESSAMENTO DE {ano_alvo} ---")

# %%
# ==============================================================================
# 5. EXECUÇÃO DO SCRIPT
# ==============================================================================

if __name__ == "__main__":
    ANO_A_PROCESSAR = "2020"
    NUMERO_DE_THREADS = 2 # Defina quantos navegadores rodarão em paralelo

    processar_ano_em_paralelo(
        ano_alvo=ANO_A_PROCESSAR,
        max_workers=NUMERO_DE_THREADS
    )
# Out:
# [MainThread] - 2025-07-15 07:09:26,477 - INFO - [processar_ano_em_paralelo] - --- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE 2020 ---
# [MainThread] - 2025-07-15 07:09:26,478 - INFO - [processar_ano_em_paralelo] - Fase 1: Coletando todos os links de detalhes...
# [MainThread] - 2025-07-15 07:09:26,480 - INFO - [start_driver] - Iniciando e configurando instância do Chrome...
# [MainThread] - 2025-07-15 07:09:44,148 - INFO - [selecionar_dropdown] - Selecionando: Pagamento
# [MainThread] - 2025-07-15 07:09:44,332 - INFO - [selecionar_dropdown] - Selecionando: 2020
# [MainThread] - 2025-07-15 07:09:53,816 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 1
# [MainThread] - 2025-07-15 07:10:02,850 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 2
# [MainThread] - 2025-07-15 07:10:11,854 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 3
# [MainThread] - 2025-07-15 07:10:20,948 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 4
# [MainThread] - 2025-07-15 07:10:30,005 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 5
# [MainThread] - 2025-07-15 07:10:39,067 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 6
# [MainThread] - 2025-07-15 07:10:48,070 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 7
# [MainThread] - 2025-07-15 07:10:57,095 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 8
# [MainThread] - 2025-07-15 07:11:06,125 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 9
# [MainThread] - 2025-07-15 07:11:15,160 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 10
# [MainThread] - 2025-07-15 07:11:24,197 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 11
# [MainThread] - 2025-07-15 07:11:33,229 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 12
# [MainThread] - 2025-07-15 07:11:42,315 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 13
# [MainThread] - 2025-07-15 07:11:51,392 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 14
# [MainThread] - 2025-07-15 07:12:00,406 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 15
# [MainThread] - 2025-07-15 07:12:09,454 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 16
# [MainThread] - 2025-07-15 07:12:18,839 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 17
# [MainThread] - 2025-07-15 07:12:27,930 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 18
# [MainThread] - 2025-07-15 07:12:37,053 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 19
# [MainThread] - 2025-07-15 07:12:46,104 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 20
# [MainThread] - 2025-07-15 07:12:55,178 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 21
# [MainThread] - 2025-07-15 07:13:04,295 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 22
# [MainThread] - 2025-07-15 07:13:13,354 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 23
# [MainThread] - 2025-07-15 07:13:22,390 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 24
# [MainThread] - 2025-07-15 07:13:31,400 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 25
# [MainThread] - 2025-07-15 07:13:40,437 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 26
# [MainThread] - 2025-07-15 07:13:49,473 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 27
# [MainThread] - 2025-07-15 07:13:58,522 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 28
# [MainThread] - 2025-07-15 07:14:07,556 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 29
# [MainThread] - 2025-07-15 07:14:16,848 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 30
# [MainThread] - 2025-07-15 07:14:25,882 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 31
# [MainThread] - 2025-07-15 07:14:34,883 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 32
# [MainThread] - 2025-07-15 07:14:43,976 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 33
# [MainThread] - 2025-07-15 07:14:52,991 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 34
# [MainThread] - 2025-07-15 07:15:02,044 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 35
# [MainThread] - 2025-07-15 07:15:11,069 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 36
# [MainThread] - 2025-07-15 07:15:20,072 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 37
# [MainThread] - 2025-07-15 07:15:29,117 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 38
# [MainThread] - 2025-07-15 07:15:38,227 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 39
# [MainThread] - 2025-07-15 07:15:47,248 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 40
# [MainThread] - 2025-07-15 07:15:56,300 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 41
# [MainThread] - 2025-07-15 07:16:05,354 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 42
# [MainThread] - 2025-07-15 07:16:15,346 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 43
# [MainThread] - 2025-07-15 07:16:24,510 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 44
# [MainThread] - 2025-07-15 07:16:33,515 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 45
# [MainThread] - 2025-07-15 07:16:42,550 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 46
# [MainThread] - 2025-07-15 07:16:51,609 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 47
# [MainThread] - 2025-07-15 07:17:00,634 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 48
# [MainThread] - 2025-07-15 07:17:09,650 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 49
# [MainThread] - 2025-07-15 07:17:18,707 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 50
# [MainThread] - 2025-07-15 07:17:27,720 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 51
# [MainThread] - 2025-07-15 07:17:36,831 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 52
# [MainThread] - 2025-07-15 07:17:45,871 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 53
# [MainThread] - 2025-07-15 07:17:54,898 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 54
# [MainThread] - 2025-07-15 07:18:03,922 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 55
# [MainThread] - 2025-07-15 07:18:12,938 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 56
# [MainThread] - 2025-07-15 07:18:21,953 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 57
# [MainThread] - 2025-07-15 07:18:30,975 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 58
# [MainThread] - 2025-07-15 07:18:40,000 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 59
# [MainThread] - 2025-07-15 07:18:49,004 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 60
# [MainThread] - 2025-07-15 07:18:58,057 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 61
# [MainThread] - 2025-07-15 07:19:07,104 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 62
# [MainThread] - 2025-07-15 07:19:16,180 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 63
# [MainThread] - 2025-07-15 07:19:25,197 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 64
# [MainThread] - 2025-07-15 07:19:34,212 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 65
# [MainThread] - 2025-07-15 07:19:43,280 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 66
# [MainThread] - 2025-07-15 07:19:52,314 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 67
# [MainThread] - 2025-07-15 07:20:01,321 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 68
# [MainThread] - 2025-07-15 07:20:10,366 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 69
# [MainThread] - 2025-07-15 07:20:19,392 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 70
# [MainThread] - 2025-07-15 07:20:28,430 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 71
# [MainThread] - 2025-07-15 07:20:37,442 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 72
# [MainThread] - 2025-07-15 07:20:46,502 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 73
# [MainThread] - 2025-07-15 07:20:55,518 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 74
# [MainThread] - 2025-07-15 07:21:04,543 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 75
# [MainThread] - 2025-07-15 07:21:13,595 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 76
# [MainThread] - 2025-07-15 07:21:22,659 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 77
# [MainThread] - 2025-07-15 07:21:31,678 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 78
# [MainThread] - 2025-07-15 07:21:40,702 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 79
# [MainThread] - 2025-07-15 07:21:49,733 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 80
# [MainThread] - 2025-07-15 07:21:58,735 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 81
# [MainThread] - 2025-07-15 07:22:07,766 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 82
# [MainThread] - 2025-07-15 07:22:16,790 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 83
# [MainThread] - 2025-07-15 07:22:25,792 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 84
# [MainThread] - 2025-07-15 07:22:34,848 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 85
# [MainThread] - 2025-07-15 07:22:43,891 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 86
# [MainThread] - 2025-07-15 07:22:52,939 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 87
# [MainThread] - 2025-07-15 07:23:01,947 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 88
# [MainThread] - 2025-07-15 07:23:11,034 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 89
# [MainThread] - 2025-07-15 07:23:20,077 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 90
# [MainThread] - 2025-07-15 07:23:29,129 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 91
# [MainThread] - 2025-07-15 07:23:38,228 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 92
# [MainThread] - 2025-07-15 07:23:47,287 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 93
# [MainThread] - 2025-07-15 07:23:56,323 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 94
# [MainThread] - 2025-07-15 07:24:05,366 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 95
# [MainThread] - 2025-07-15 07:24:14,389 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 96
# [MainThread] - 2025-07-15 07:24:23,449 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 97
# [MainThread] - 2025-07-15 07:24:32,453 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 98
# [MainThread] - 2025-07-15 07:24:41,481 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 99
# [MainThread] - 2025-07-15 07:24:50,492 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 100
# [MainThread] - 2025-07-15 07:24:59,522 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 101
# [MainThread] - 2025-07-15 07:25:08,542 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 102
# [MainThread] - 2025-07-15 07:25:17,598 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 103
# [MainThread] - 2025-07-15 07:25:26,614 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 104
# [MainThread] - 2025-07-15 07:25:35,653 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 105
# [MainThread] - 2025-07-15 07:25:44,712 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 106
# [MainThread] - 2025-07-15 07:25:53,763 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 107
# [MainThread] - 2025-07-15 07:26:02,822 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 108
# [MainThread] - 2025-07-15 07:26:11,854 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 109
# [MainThread] - 2025-07-15 07:26:20,901 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 110
# [MainThread] - 2025-07-15 07:26:29,895 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 111
# [MainThread] - 2025-07-15 07:26:38,917 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 112
# [MainThread] - 2025-07-15 07:26:47,919 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 113
# [MainThread] - 2025-07-15 07:26:56,927 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 114
# [MainThread] - 2025-07-15 07:27:05,968 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 115
# [MainThread] - 2025-07-15 07:27:14,980 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 116
# [MainThread] - 2025-07-15 07:27:23,981 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 117
# [MainThread] - 2025-07-15 07:27:33,000 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 118
# [MainThread] - 2025-07-15 07:27:42,043 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 119
# [MainThread] - 2025-07-15 07:27:51,068 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 120
# [MainThread] - 2025-07-15 07:28:00,100 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 121
# [MainThread] - 2025-07-15 07:28:09,108 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 122
# [MainThread] - 2025-07-15 07:28:18,129 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 123
# [MainThread] - 2025-07-15 07:28:27,137 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 124
# [MainThread] - 2025-07-15 07:28:36,134 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 125
# [MainThread] - 2025-07-15 07:28:45,169 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 126
# [MainThread] - 2025-07-15 07:28:54,200 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 127
# [MainThread] - 2025-07-15 07:29:03,199 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 128
# [MainThread] - 2025-07-15 07:29:12,209 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 129
# [MainThread] - 2025-07-15 07:29:21,227 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 130
# [MainThread] - 2025-07-15 07:29:30,273 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 131
# [MainThread] - 2025-07-15 07:29:39,317 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 132
# [MainThread] - 2025-07-15 07:29:48,342 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 133
# [MainThread] - 2025-07-15 07:29:57,415 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 134
# [MainThread] - 2025-07-15 07:30:06,517 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 135
# [MainThread] - 2025-07-15 07:30:15,558 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 136
# [MainThread] - 2025-07-15 07:30:24,563 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 137
# [MainThread] - 2025-07-15 07:30:33,610 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 138
# [MainThread] - 2025-07-15 07:30:42,656 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 139
# [MainThread] - 2025-07-15 07:30:51,660 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 140
# [MainThread] - 2025-07-15 07:31:00,686 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 141
# [MainThread] - 2025-07-15 07:31:09,713 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 142
# [MainThread] - 2025-07-15 07:31:18,759 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 143
# [MainThread] - 2025-07-15 07:31:27,789 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 144
# [MainThread] - 2025-07-15 07:31:36,846 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 145
# [MainThread] - 2025-07-15 07:31:45,940 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 146
# [MainThread] - 2025-07-15 07:31:54,966 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 147
# [MainThread] - 2025-07-15 07:32:03,976 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 148
# [MainThread] - 2025-07-15 07:32:13,020 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 149
# [MainThread] - 2025-07-15 07:32:22,043 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 150
# [MainThread] - 2025-07-15 07:32:31,064 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 151
# [MainThread] - 2025-07-15 07:32:40,127 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 152
# [MainThread] - 2025-07-15 07:32:49,125 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 153
# [MainThread] - 2025-07-15 07:32:58,184 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 154
# [MainThread] - 2025-07-15 07:33:07,202 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 155
# [MainThread] - 2025-07-15 07:33:16,222 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 156
# [MainThread] - 2025-07-15 07:33:25,254 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 157
# [MainThread] - 2025-07-15 07:33:34,299 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 158
# [MainThread] - 2025-07-15 07:33:43,355 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 159
# [MainThread] - 2025-07-15 07:33:52,369 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 160
# [MainThread] - 2025-07-15 07:34:01,395 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 161
# [MainThread] - 2025-07-15 07:34:10,449 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 162
# [MainThread] - 2025-07-15 07:34:19,477 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 163
# [MainThread] - 2025-07-15 07:34:28,503 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 164
# [MainThread] - 2025-07-15 07:34:37,630 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 165
# [MainThread] - 2025-07-15 07:34:46,701 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 166
# [MainThread] - 2025-07-15 07:34:55,778 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 167
# [MainThread] - 2025-07-15 07:35:04,801 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 168
# [MainThread] - 2025-07-15 07:35:13,837 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 169
# [MainThread] - 2025-07-15 07:35:22,874 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 170
# [MainThread] - 2025-07-15 07:35:31,898 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 171
# [MainThread] - 2025-07-15 07:35:40,940 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 172
# [MainThread] - 2025-07-15 07:35:49,948 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 173
# [MainThread] - 2025-07-15 07:35:58,958 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 174
# [MainThread] - 2025-07-15 07:36:07,987 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 175
# [MainThread] - 2025-07-15 07:36:17,010 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 176
# [MainThread] - 2025-07-15 07:36:26,025 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 177
# [MainThread] - 2025-07-15 07:36:35,094 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 178
# [MainThread] - 2025-07-15 07:36:44,126 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 179
# [MainThread] - 2025-07-15 07:36:53,185 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 180
# [MainThread] - 2025-07-15 07:37:02,224 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 181
# [MainThread] - 2025-07-15 07:37:11,220 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 182
# [MainThread] - 2025-07-15 07:37:20,277 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 183
# [MainThread] - 2025-07-15 07:37:29,308 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 184
# [MainThread] - 2025-07-15 07:37:38,330 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 185
# [MainThread] - 2025-07-15 07:37:47,346 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 186
# [MainThread] - 2025-07-15 07:37:56,386 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 187
# [MainThread] - 2025-07-15 07:38:05,429 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 188
# [MainThread] - 2025-07-15 07:38:14,440 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 189
# [MainThread] - 2025-07-15 07:38:23,431 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 190
# [MainThread] - 2025-07-15 07:38:32,465 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 191
# [MainThread] - 2025-07-15 07:38:41,498 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 192
# [MainThread] - 2025-07-15 07:38:50,515 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 193
# [MainThread] - 2025-07-15 07:38:59,527 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 194
# [MainThread] - 2025-07-15 07:39:08,544 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 195
# [MainThread] - 2025-07-15 07:39:17,565 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 196
# [MainThread] - 2025-07-15 07:39:26,649 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 197
# [MainThread] - 2025-07-15 07:39:35,674 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 198
# [MainThread] - 2025-07-15 07:39:44,777 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 199
# [MainThread] - 2025-07-15 07:39:53,803 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 200
# [MainThread] - 2025-07-15 07:40:02,884 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 201
# [MainThread] - 2025-07-15 07:40:11,919 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 202
# [MainThread] - 2025-07-15 07:40:21,013 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 203
# [MainThread] - 2025-07-15 07:40:30,051 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 204
# [MainThread] - 2025-07-15 07:40:39,115 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 205
# [MainThread] - 2025-07-15 07:40:48,169 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 206
# [MainThread] - 2025-07-15 07:40:57,282 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 207
# [MainThread] - 2025-07-15 07:41:06,274 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 208
# [MainThread] - 2025-07-15 07:41:15,279 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 209
# [MainThread] - 2025-07-15 07:41:24,362 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 210
# [MainThread] - 2025-07-15 07:41:33,404 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 211
# [MainThread] - 2025-07-15 07:41:42,451 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 212
# [MainThread] - 2025-07-15 07:41:51,501 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 213
# [MainThread] - 2025-07-15 07:42:00,540 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 214
# [MainThread] - 2025-07-15 07:42:09,560 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 215
# [MainThread] - 2025-07-15 07:42:18,620 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 216
# [MainThread] - 2025-07-15 07:42:27,662 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 217
# [MainThread] - 2025-07-15 07:42:36,721 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 218
# [MainThread] - 2025-07-15 07:42:45,760 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 219
# [MainThread] - 2025-07-15 07:42:54,761 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 220
# [MainThread] - 2025-07-15 07:43:03,813 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 221
# [MainThread] - 2025-07-15 07:43:12,841 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 222
# [MainThread] - 2025-07-15 07:43:21,853 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 223
# [MainThread] - 2025-07-15 07:43:30,856 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 224
# [MainThread] - 2025-07-15 07:43:39,893 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 225
# [MainThread] - 2025-07-15 07:43:48,925 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 226
# [MainThread] - 2025-07-15 07:43:57,956 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 227
# [MainThread] - 2025-07-15 07:44:07,052 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 228
# [MainThread] - 2025-07-15 07:44:16,085 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 229
# [MainThread] - 2025-07-15 07:44:25,118 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 230
# [MainThread] - 2025-07-15 07:44:34,150 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 231
# [MainThread] - 2025-07-15 07:44:43,185 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 232
# [MainThread] - 2025-07-15 07:44:52,209 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 233
# [MainThread] - 2025-07-15 07:45:01,267 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 234
# [MainThread] - 2025-07-15 07:45:10,293 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 235
# [MainThread] - 2025-07-15 07:45:19,299 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 236
# [MainThread] - 2025-07-15 07:45:28,384 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 237
# [MainThread] - 2025-07-15 07:45:37,438 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 238
# [MainThread] - 2025-07-15 07:45:46,479 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 239
# [MainThread] - 2025-07-15 07:45:55,507 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 240
# [MainThread] - 2025-07-15 07:46:04,609 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 241
# [MainThread] - 2025-07-15 07:46:13,647 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 242
# [MainThread] - 2025-07-15 07:46:22,730 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 243
# [MainThread] - 2025-07-15 07:46:31,785 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 244
# [MainThread] - 2025-07-15 07:46:40,801 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 245
# [MainThread] - 2025-07-15 07:46:49,844 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 246
# [MainThread] - 2025-07-15 07:46:58,851 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 247
# [MainThread] - 2025-07-15 07:47:07,876 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 248
# [MainThread] - 2025-07-15 07:47:16,909 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 249
# [MainThread] - 2025-07-15 07:47:25,964 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 250
# [MainThread] - 2025-07-15 07:47:34,998 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 251
# [MainThread] - 2025-07-15 07:47:44,082 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 252
# [MainThread] - 2025-07-15 07:47:53,101 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 253
# [MainThread] - 2025-07-15 07:48:02,157 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 254
# [MainThread] - 2025-07-15 07:48:11,170 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 255
# [MainThread] - 2025-07-15 07:48:20,187 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 256
# [MainThread] - 2025-07-15 07:48:29,224 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 257
# [MainThread] - 2025-07-15 07:48:38,262 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 258
# [MainThread] - 2025-07-15 07:48:47,283 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 259
# [MainThread] - 2025-07-15 07:48:56,282 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 260
# [MainThread] - 2025-07-15 07:49:05,331 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 261
# [MainThread] - 2025-07-15 07:49:14,404 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 262
# [MainThread] - 2025-07-15 07:49:23,429 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 263
# [MainThread] - 2025-07-15 07:49:32,434 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 264
# [MainThread] - 2025-07-15 07:49:41,523 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 265
# [MainThread] - 2025-07-15 07:49:50,539 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 266
# [MainThread] - 2025-07-15 07:49:59,581 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 267
# [MainThread] - 2025-07-15 07:50:08,593 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 268
# [MainThread] - 2025-07-15 07:50:17,629 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 269
# [MainThread] - 2025-07-15 07:50:26,663 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 270
# [MainThread] - 2025-07-15 07:50:35,765 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 271
# [MainThread] - 2025-07-15 07:50:44,797 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 272
# [MainThread] - 2025-07-15 07:50:53,810 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 273
# [MainThread] - 2025-07-15 07:51:02,851 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 274
# [MainThread] - 2025-07-15 07:51:11,876 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 275
# [MainThread] - 2025-07-15 07:51:20,921 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 276
# [MainThread] - 2025-07-15 07:51:29,897 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 277
# [MainThread] - 2025-07-15 07:51:38,934 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 278
# [MainThread] - 2025-07-15 07:51:47,955 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 279
# [MainThread] - 2025-07-15 07:51:56,968 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 280
# [MainThread] - 2025-07-15 07:52:05,974 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 281
# [MainThread] - 2025-07-15 07:52:14,990 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 282
# [MainThread] - 2025-07-15 07:52:23,989 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 283
# [MainThread] - 2025-07-15 07:52:33,008 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 284
# [MainThread] - 2025-07-15 07:52:42,047 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 285
# [MainThread] - 2025-07-15 07:52:51,098 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 286
# [MainThread] - 2025-07-15 07:53:00,142 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 287
# [MainThread] - 2025-07-15 07:53:09,190 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 288
# [MainThread] - 2025-07-15 07:53:18,197 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 289
# [MainThread] - 2025-07-15 07:53:27,267 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 290
# [MainThread] - 2025-07-15 07:53:36,327 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 291
# [MainThread] - 2025-07-15 07:53:45,369 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 292
# [MainThread] - 2025-07-15 07:53:54,394 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 293
# [MainThread] - 2025-07-15 07:54:03,543 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 294
# [MainThread] - 2025-07-15 07:54:12,576 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 295
# [MainThread] - 2025-07-15 07:54:21,591 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 296
# [MainThread] - 2025-07-15 07:54:30,632 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 297
# [MainThread] - 2025-07-15 07:54:39,660 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 298
# [MainThread] - 2025-07-15 07:54:48,688 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 299
# [MainThread] - 2025-07-15 07:54:57,723 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 300
# [MainThread] - 2025-07-15 07:55:06,780 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 301
# [MainThread] - 2025-07-15 07:55:15,808 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 302
# [MainThread] - 2025-07-15 07:55:24,865 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 303
# [MainThread] - 2025-07-15 07:55:33,875 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 304
# [MainThread] - 2025-07-15 07:55:42,916 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 305
# [MainThread] - 2025-07-15 07:55:51,923 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 306
# [MainThread] - 2025-07-15 07:56:00,969 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 307
# [MainThread] - 2025-07-15 07:56:09,991 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 308
# [MainThread] - 2025-07-15 07:56:19,049 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 309
# [MainThread] - 2025-07-15 07:56:28,066 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 310
# [MainThread] - 2025-07-15 07:56:37,076 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 311
# [MainThread] - 2025-07-15 07:56:46,099 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 312
# [MainThread] - 2025-07-15 07:56:55,137 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 313
# [MainThread] - 2025-07-15 07:57:04,155 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 314
# [MainThread] - 2025-07-15 07:57:13,173 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 315
# [MainThread] - 2025-07-15 07:57:22,183 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 316
# [MainThread] - 2025-07-15 07:57:31,216 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 317
# [MainThread] - 2025-07-15 07:57:40,227 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 318
# [MainThread] - 2025-07-15 07:57:49,237 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 319
# [MainThread] - 2025-07-15 07:57:58,229 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 320
# [MainThread] - 2025-07-15 07:58:07,266 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 321
# [MainThread] - 2025-07-15 07:58:16,311 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 322
# [MainThread] - 2025-07-15 07:58:25,337 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 323
# [MainThread] - 2025-07-15 07:58:34,364 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 324
# [MainThread] - 2025-07-15 07:58:43,353 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 325
# [MainThread] - 2025-07-15 07:58:52,388 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 326
# [MainThread] - 2025-07-15 07:59:01,449 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 327
# [MainThread] - 2025-07-15 07:59:10,438 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 328
# [MainThread] - 2025-07-15 07:59:19,480 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 329
# [MainThread] - 2025-07-15 07:59:28,528 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 330
# [MainThread] - 2025-07-15 07:59:37,876 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 331
# [MainThread] - 2025-07-15 07:59:46,957 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 332
# [MainThread] - 2025-07-15 07:59:56,023 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 333
# [MainThread] - 2025-07-15 08:00:05,059 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 334
# [MainThread] - 2025-07-15 08:00:14,142 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 335
# [MainThread] - 2025-07-15 08:00:23,184 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 336
# [MainThread] - 2025-07-15 08:00:32,191 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 337
# [MainThread] - 2025-07-15 08:00:41,270 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 338
# [MainThread] - 2025-07-15 08:00:50,348 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 339
# [MainThread] - 2025-07-15 08:00:59,393 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 340
# [MainThread] - 2025-07-15 08:01:08,508 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 341
# [MainThread] - 2025-07-15 08:01:17,552 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 342
# [MainThread] - 2025-07-15 08:01:26,582 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 343
# [MainThread] - 2025-07-15 08:01:35,616 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 344
# [MainThread] - 2025-07-15 08:01:44,659 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 345
# [MainThread] - 2025-07-15 08:01:53,690 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 346
# [MainThread] - 2025-07-15 08:02:02,749 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 347
# [MainThread] - 2025-07-15 08:02:11,758 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 348
# [MainThread] - 2025-07-15 08:02:20,789 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 349
# [MainThread] - 2025-07-15 08:02:29,829 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 350
# [MainThread] - 2025-07-15 08:02:38,850 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 351
# [MainThread] - 2025-07-15 08:02:47,874 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 352
# [MainThread] - 2025-07-15 08:02:56,876 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 353
# [MainThread] - 2025-07-15 08:03:05,932 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 354
# [MainThread] - 2025-07-15 08:03:14,958 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 355
# [MainThread] - 2025-07-15 08:03:23,977 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 356
# [MainThread] - 2025-07-15 08:03:33,020 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 357
# [MainThread] - 2025-07-15 08:03:42,041 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 358
# [MainThread] - 2025-07-15 08:03:51,097 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 359
# [MainThread] - 2025-07-15 08:04:00,099 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 360
# [MainThread] - 2025-07-15 08:04:09,165 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 361
# [MainThread] - 2025-07-15 08:04:18,157 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 362
# [MainThread] - 2025-07-15 08:04:27,184 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 363
# [MainThread] - 2025-07-15 08:04:36,289 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 364
# [MainThread] - 2025-07-15 08:04:45,472 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 365
# [MainThread] - 2025-07-15 08:04:54,511 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 366
# [MainThread] - 2025-07-15 08:05:03,571 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 367
# [MainThread] - 2025-07-15 08:05:12,599 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 368
# [MainThread] - 2025-07-15 08:05:21,639 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 369
# [MainThread] - 2025-07-15 08:05:30,674 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 370
# [MainThread] - 2025-07-15 08:05:39,700 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 371
# [MainThread] - 2025-07-15 08:05:48,709 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 372
# [MainThread] - 2025-07-15 08:05:57,827 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 373
# [MainThread] - 2025-07-15 08:06:06,893 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 374
# [MainThread] - 2025-07-15 08:06:15,933 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 375
# [MainThread] - 2025-07-15 08:06:24,968 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 376
# [MainThread] - 2025-07-15 08:06:34,017 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 377
# [MainThread] - 2025-07-15 08:06:43,054 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 378
# [MainThread] - 2025-07-15 08:06:52,115 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 379
# [MainThread] - 2025-07-15 08:07:01,147 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 380
# [MainThread] - 2025-07-15 08:07:10,170 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 381
# [MainThread] - 2025-07-15 08:07:19,234 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 382
# [MainThread] - 2025-07-15 08:07:28,256 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 383
# [MainThread] - 2025-07-15 08:07:37,292 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 384
# [MainThread] - 2025-07-15 08:07:46,371 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 385
# [MainThread] - 2025-07-15 08:07:55,429 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 386
# ...
# [Worker-948] - 2025-07-15 09:27:13,766 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45359/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:15,733 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45358/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:17,521 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45357/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:20,503 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45354/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:22,476 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45353/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:27:24,263 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/579/40052/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:24,505 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45352/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:26,410 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/292/45351/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:27:26,892 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/579/40011/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:34,689 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/293/45368/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:37,427 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/293/45367/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:39,401 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/293/45366/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:27:43,441 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/580/39003/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:56,972 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45393/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:27:58,898 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45392/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:00,493 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45391/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:01,915 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45390/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:03,295 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45389/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:04,610 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45388/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:06,009 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45387/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:07,164 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/581/39004/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:07,452 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/295/45386/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:12,741 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45401/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:12,861 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/582/39030/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:14,033 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45400/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:15,314 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45399/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:15,790 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/583/38885/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:16,664 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45398/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:17,968 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45397/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:18,690 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/583/38866/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:19,253 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45396/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:20,607 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45395/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:22,075 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/296/45394/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:23,239 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/584/38897/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:24,882 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/584/38895/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:25,840 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/584/38894/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:28,118 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/584/38891/2020?lc173=true&covid19=true
# [Worker-948] - 2025-07-15 09:28:28,876 - INFO - [worker_extrair_detalhes] - Worker finalizado.
# Processando Detalhes de Pacatuba de 2020:  50%|█████     | 1/2 [49:11<49:11, 2951.89s/it][Worker-632] - 2025-07-15 09:28:30,311 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/585/39028/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:31,789 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/585/38577/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:32,674 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/585/38576/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:36,241 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/585/39029/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:37,739 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/586/38787/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:38,575 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/586/38786/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:46,791 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/587/38901/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:56,984 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/588/38909/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:28:57,816 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/588/38908/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:29:17,182 - INFO - [worker_extrair_detalhes] - Royalties encontrados (Fonte: '15300000  transferencia da uniao referente a royalties do petroleo'). Extraindo todos os dados do link: https://transparencia.pacatuba.se.gov.br/portal/despesa/pagamento/189/591/39027/2020?lc173=true&covid19=true
# [Worker-632] - 2025-07-15 09:29:31,288 - INFO - [worker_extrair_detalhes] - Worker finalizado.
# Processando Detalhes de Pacatuba de 2020: 100%|██████████| 2/2 [50:14<00:00, 1507.15s/it]
# [MainThread] - 2025-07-15 09:29:31,340 - INFO - [processar_ano_em_paralelo] - Processamento concluído. 1185 registros salvos em: dados_finais\pacatuba\royalties_pacatuba_2020.csv
# [MainThread] - 2025-07-15 09:29:31,342 - INFO - [processar_ano_em_paralelo] - --- FINALIZADO PROCESSAMENTO DE 2020 ---

# %% [markdown]
# # FIM =)
