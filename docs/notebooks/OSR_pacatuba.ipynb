# %%
# ==============================================================================
# 1. IMPORTAÇÕES E LOGGER PARA PARALELISMO
# ==============================================================================

import os
import time
import logging
import threading
from typing import List
import pandas as pd
import csv
import unicodedata
import re
from concurrent.futures import ThreadPoolExecutor, as_completed

import numpy # Usado para dividir a lista de tarefas
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException

from webdriver_manager.chrome import ChromeDriverManager

# Objeto de armazenamento de dados que é local (privado) para cada thread
log_context = threading.local()

class TaskIdFilter(logging.Filter):
    """Filtro para adicionar um ID de tarefa/thread aos registros de log."""
    def filter(self, record: logging.LogRecord) -> bool:
        record.task_id = getattr(log_context, 'task_id', 'MainThread')
        return True

def setup_logging(log_file: str) -> logging.Logger:
    os.makedirs(os.path.dirname(log_file), exist_ok=True)
    logger = logging.getLogger('osr_pacatuba')
    logger.setLevel(logging.INFO)

    if logger.hasHandlers():
        logger.handlers.clear()

    formatter = logging.Formatter("[%(task_id)s] - %(asctime)s - %(levelname)s - [%(funcName)s] - %(message)s")
    task_filter = TaskIdFilter()

    file_handler = logging.FileHandler(log_file, mode='w', encoding='utf-8')
    file_handler.setFormatter(formatter)
    file_handler.addFilter(task_filter)

    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    console_handler.addFilter(task_filter)

    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    # Reduz o ruído de bibliotecas externas
    logging.getLogger('selenium').setLevel(logging.WARNING)
    logging.getLogger('urllib3').setLevel(logging.WARNING)
    logging.getLogger('WDM').setLevel(logging.WARNING)

    return logger

# A variável logger será inicializada dentro da função de orquestração
logger = None

# %%
# ==============================================================================
# 2. CONSTANTES E FUNÇÕES AUXILIARES
# ==============================================================================

# Agora os termos são os códigos, conforme seu código
TERMOS_ROYALTIES = ["royaltie", "royalty", "petroleo"]

RE_REMOVE_PUNCTUATION = re.compile(r'[^a-zA-Z0-9\s]')

def normalizar(texto: str) -> str:
    """
    Normaliza um texto removendo acentos, pontuações e convertendo para minúsculas.
    """
    if not isinstance(texto, str):
        return ""
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = RE_REMOVE_PUNCTUATION.sub('', texto)
    return texto.lower()

# %%
# ==============================================================================
# 3. DRIVER E INTERAÇÕES COM A PÁGINA (start_driver ATUALIZADO)
# ==============================================================================

def start_driver(headless=False) -> webdriver.Chrome:
    logger.info("Iniciando e configurando instância do Chrome...")
    options = webdriver.ChromeOptions()

    if headless:
        options.add_argument("--headless=new")
        options.add_argument("--disable-gpu")
        options.add_argument("--no-sandbox")
    else:
        options.add_argument('--window-size=1920,1080')
        options.add_argument("--disable-blink-features=AutomationControlled")
        options.add_experimental_option("excludeSwitches", ["enable-automation"])
    
    # A função agora apenas cria e retorna o driver, sem navegar.
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    return driver


def selecionar_dropdown(driver, container_id, texto):
    try:
        logger.info(f"Selecionando: {texto}")
        trigger = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//span[@aria-labelledby='{container_id}']"))
        )
        trigger.click()
        opcao = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, f"//li[contains(@class, 'select2-results__option') and normalize-space(.)='{texto}']"))
        )
        opcao.click()
    except Exception as e:
        logger.error(f"Erro ao selecionar {texto} no campo {container_id}: {e}")
        raise

def ir_para_proxima_pagina(driver):
    try:
        proxima_pagina_locator = (By.XPATH, "//a[contains(@class, 'page-link')][i[contains(@class, 'next')]]")
        botao = driver.find_element(*proxima_pagina_locator)
        parent_li = botao.find_element(By.XPATH, "./parent::li")
        
        if "disabled" in parent_li.get_attribute("class"):
            logger.info("Última página alcançada.")
            return False

        botao.click()
        logger.info("Navegando para a próxima página de resultados.")
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        return True
    except NoSuchElementException:
        logger.info("Botão 'Próxima Página' não encontrado. Fim da paginação.")
        return False

# %%
# ==============================================================================
# 4. WORKER PARALELO E ORQUESTRAÇÃO
# ==============================================================================
def worker_extrair_detalhes(links: List[str], ano_alvo: str) -> List[dict]:
    """
    Função 'worker' para threads. Otimizada para verificar a fonte de recurso
    primeiro, antes de extrair todos os outros dados.
    """
    log_context.task_id = f"Worker-{threading.get_ident() % 1000}"
    logger = logging.getLogger('osr_pacatuba')
    
    logger.info(f"Worker iniciado. Processando {len(links)} links.")
    
    dados_coletados_pela_thread = []
    driver = None
    try:
        driver = start_driver(headless=True)
        
        for i, link in enumerate(links):
            try:
                logger.debug(f"Acessando link {i+1}/{len(links)}.")
                driver.get(link)
                
                # Aguarda o elemento mais básico da página de detalhes para garantir o carregamento
                WebDriverWait(driver, 20).until(
                    EC.visibility_of_element_located((By.ID, "table-dados"))
                )

                # Mapa de XPaths para todos os campos na página de detalhes.
                XPATHS_DETALHES = {           
                    'empenho':          '//*[@id="table-dados"]/tbody/tr[2]/td[1]',
                    'credor':           '//*[@id="table-dados"]/tbody/tr[2]/td[2]',
                    'data_nota':        '//*[@id="table-dados"]/tbody/tr[2]/td[3]',

                    'processo':         '//*[@id="table-dados"]/tbody/tr[4]/th[1]',
                    'fonte_recurso':    '//*[@id="table-dados"]/tbody/tr[4]/th[2]',            
                    'numero_documento': '//*[@id="table-dados"]/tbody/tr[4]/th[3]',

                    'valor_pago':       '//*[@id="table-dados"]/tbody/tr[6]/td[1]',
                    'valor_retido':     '//*[@id="table-dados"]/tbody/tr[6]/td[2]',
                    'forma_pagamento':  '//*[@id="table-dados"]/tbody/tr[6]/td[3]',
                    
                    'historico':        '//*[@id="table-historico"]/tbody/tr/td',
                    'relacionado_covid':'//*[@id="table-outras-informacoes"]/tbody/tr/td[1]',
                    'relacionado_LC173':'//*[@id="table-outras-informacoes"]/tbody/tr/td[2]'
                }
                
                # --- ETAPA 1: Extrair APENAS a Fonte de Recurso para verificação ---
                logger.debug("Verificando a Fonte de Recurso primeiro...")
                fonte_recurso_texto = None
                try:
                    # Usa o XPath específico para a fonte de recurso
                    fonte_recurso_element = driver.find_element(By.XPATH, XPATHS_DETALHES['fonte_recurso'])
                    fonte_recurso_texto = fonte_recurso_element.text.strip()
                    fonte_recurso_texto = normalizar(fonte_recurso_texto)
                    
                except NoSuchElementException:
                    logger.warning(f"Campo 'fonte_recurso' não encontrado no link {link}. Pulando.")
                    continue # Pula para o próximo link

                # --- ETAPA 2: Verificar se é de royalties ANTES de extrair o resto ---
                if fonte_recurso_texto and any(termo in fonte_recurso_texto for termo in TERMOS_ROYALTIES):
                    logger.info(f"Royalties encontrados (Fonte: '{fonte_recurso_texto}'). Extraindo todos os dados do link: {link}")
                    
                    # --- ETAPA 3: Se for royalties, extrair todos os outros campos ---
                    dados_completos = {'fonte_recurso': fonte_recurso_texto}
                    
                    for nome_campo, xpath in XPATHS_DETALHES.items():
                        if nome_campo == 'fonte_recurso': # Já pegamos este
                            continue
                        try:
                            dados_completos[nome_campo] = driver.find_element(By.XPATH, xpath).text.strip()
                        except NoSuchElementException:
                            dados_completos[nome_campo] = None
                    
                    dados_completos['link_detalhe'] = link
                    dados_coletados_pela_thread.append(dados_completos)

                else:
                    logger.debug(f"Link não é de royalties. Fonte: '{fonte_recurso_texto}'. Pulando extração detalhada.")

            except Exception as e_link:
                logger.error(f"Erro ao processar o link {link}: {e_link}")
                continue # Continua para o próximo link
    finally:
        if driver: 
            driver.quit()
        logger.info("Worker finalizado.")
    
    return dados_coletados_pela_thread


def processar_ano_em_paralelo(ano_alvo: str, max_workers: int = 4):
    """
    Orquestra o processo: coleta todos os links e depois distribui a extração.
    """
    global logger
    logger = setup_logging(log_file=f"../logs/pacatuba/extracao_{ano_alvo}.log")
    
    logger.info(f"--- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE {ano_alvo} ---")
    
    # --- FASE 1: COLETA DE TODOS OS LINKS NA THREAD PRINCIPAL ---
    links_para_processar = []
    driver = None
    try:
        logger.info("Fase 1: Coletando todos os links de detalhes...")
        driver = start_driver(headless=True)
        url_incial = "https://transparencia.pacatuba.se.gov.br/public/portal/despesas"
        driver.get(url_incial)
        WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.TAG_NAME, 'body')))
        
        selecionar_dropdown(driver, "select2-tipo-container", "Pagamento")
        selecionar_dropdown(driver, "select2-ano-container", ano_alvo)
        
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button#filtrar.btn-buscar"))).click()
        WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table/tbody")))
        
        pagina_atual = 1
        while True:
            logger.info(f"Coletando links da página de resultados: {pagina_atual}")
            
            # =================================================================
            # AQUI ESTÁ A CORREÇÃO
            # =================================================================
            # Usando o seletor XPath específico para a coluna de detalhes
            botoes_detalhes_locator = (By.XPATH, "//td[@serigyitem='detalhesPagamento']/a")
            botoes_detalhes = WebDriverWait(driver, 10).until(
                EC.presence_of_all_elements_located(botoes_detalhes_locator)
            )
            # =================================================================
            
            for botao in botoes_detalhes:
                if link := botao.get_attribute('href'): 
                    links_para_processar.append(link)
            #break
            if not ir_para_proxima_pagina(driver): 
                break
            pagina_atual += 1
            
    finally:
        if driver: 
            driver.quit()
    
    logger.info(f"Fase 1 concluída. Total de {len(links_para_processar)} links de detalhes coletados.")
    
    if not links_para_processar: 
        logger.warning("Nenhum link para processar. Encerrando.")
        return

    # --- FASE 2: DISTRIBUIÇÃO E PROCESSAMENTO PARALELO ---
    # (Esta parte do código permanece a mesma, pois o erro estava na coleta dos links)
    logger.info(f"Fase 2: Iniciando extração com {max_workers} workers.")
    dados_finais = []
    
    if max_workers > len(links_para_processar): max_workers = len(links_para_processar)
    
    lista_de_tarefas = numpy.array_split(links_para_processar, max_workers) if max_workers > 0 else [links_para_processar]
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(worker_extrair_detalhes, tarefa.tolist(), ano_alvo): i for i, tarefa in enumerate(lista_de_tarefas) if tarefa.size > 0}
        
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"Processando Detalhes de {ano_alvo}"):
            if resultado_parcial := future.result(): 
                dados_finais.extend(resultado_parcial)

    # --- SALVAR RESULTADOS ---
    if dados_finais:
        output_dir = os.path.join("dados_finais", "pacatuba")
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, f"royalties_pacatuba_{ano_alvo}.csv")
        
        df = pd.DataFrame(dados_finais)
        df.to_csv(output_path, index=False, sep=';', encoding='utf-8-sig')
        logger.info(f"Processamento concluído. {len(df)} registros salvos em: {output_path}")
    else:
        logger.info("Nenhum registro de royalties foi extraído.")
        
    logger.info(f"--- FINALIZADO PROCESSAMENTO DE {ano_alvo} ---")

# %%
# ==============================================================================
# 5. EXECUÇÃO DO SCRIPT
# ==============================================================================

if __name__ == "__main__":
    ANO_A_PROCESSAR = "2018"
    NUMERO_DE_THREADS = 2 # Defina quantos navegadores rodarão em paralelo

    processar_ano_em_paralelo(
        ano_alvo=ANO_A_PROCESSAR,
        max_workers=NUMERO_DE_THREADS
    )
# Out:
# [MainThread] - 2025-07-14 12:32:55,618 - INFO - [processar_ano_em_paralelo] - --- INICIANDO PROCESSAMENTO PARALELO PARA O ANO DE 2018 ---
# [MainThread] - 2025-07-14 12:32:55,620 - INFO - [processar_ano_em_paralelo] - Fase 1: Coletando todos os links de detalhes...
# [MainThread] - 2025-07-14 12:32:55,622 - INFO - [start_driver] - Iniciando e configurando instância do Chrome...
# [MainThread] - 2025-07-14 12:33:12,604 - INFO - [selecionar_dropdown] - Selecionando: Pagamento
# [MainThread] - 2025-07-14 12:33:12,817 - INFO - [selecionar_dropdown] - Selecionando: 2018
# [MainThread] - 2025-07-14 12:33:24,546 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 1
# [MainThread] - 2025-07-14 12:34:02,901 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:34:02,919 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 2
# [MainThread] - 2025-07-14 12:34:19,356 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:34:19,377 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 3
# [MainThread] - 2025-07-14 12:34:31,111 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:34:31,132 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 4
# [MainThread] - 2025-07-14 12:34:42,691 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:34:42,716 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 5
# [MainThread] - 2025-07-14 12:34:54,508 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:34:54,528 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 6
# [MainThread] - 2025-07-14 12:35:06,162 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:35:06,179 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 7
# [MainThread] - 2025-07-14 12:35:17,839 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:35:17,856 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 8
# [MainThread] - 2025-07-14 12:35:29,370 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:35:29,389 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 9
# [MainThread] - 2025-07-14 12:35:40,946 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:35:40,965 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 10
# [MainThread] - 2025-07-14 12:35:52,484 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:35:52,503 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 11
# [MainThread] - 2025-07-14 12:36:04,045 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:36:04,068 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 12
# [MainThread] - 2025-07-14 12:36:15,866 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:36:15,896 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 13
# [MainThread] - 2025-07-14 12:36:27,543 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:36:27,571 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados:
- INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 57
# [MainThread] - 2025-07-14 12:45:11,914 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:45:11,936 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 58
# [MainThread] - 2025-07-14 12:45:23,535 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:45:23,558 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 59
# [MainThread] - 2025-07-14 12:45:35,129 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:45:35,155 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 60
# [MainThread] - 2025-07-14 12:45:46,724 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:45:46,739 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 61
# [MainThread] - 2025-07-14 12:45:58,359 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:45:58,378 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 62
# [MainThread] - 2025-07-14 12:46:10,352 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:46:10,375 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 63
# [MainThread] - 2025-07-14 12:46:22,565 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:46:22,587 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 64
# [MainThread] - 2025-07-14 12:46:34,186 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:46:34,209 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 65
# [MainThread] - 2025-07-14 12:46:45,955 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:46:45,979 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 66
# [MainThread] - 2025-07-14 12:46:57,660 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:46:57,678 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 67
# [MainThread] - 2025-07-14 12:47:09,420 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:47:09,440 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 68
# [MainThread] - 2025-07-14 12:47:21,104 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:47:21,131 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 69
# [MainThread] - 2025-07-14 12:47:32,808 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:47:32,833 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 70
# [MainThread] - 2025-07-14 12:47:44,521 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:47:44,548 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 71
# [MainThread] - 2025-07-14 12:47:56,244 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:47:56,267 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 72
# [MainThread] - 2025-07-14 12:48:07,928 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:48:07,950 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 73
# [MainThread] - 2025-07-14 12:48:19,581 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:48:19,598 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 74
# [MainThread] - 2025-07-14 12:48:31,278 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:48:31,307 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 75
# [MainThread] - 2025-07-14 12:48:43,059 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:48:43,079 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 76
# [MainThread] - 2025-07-14 12:48:54,753 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:48:54,779 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 77
# [MainThread] - 2025-07-14 12:49:06,444 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:49:06,467 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 78
# [MainThread] - 2025-07-14 12:49:18,256 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:49:18,275 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 79
# [MainThread] - 2025-07-14 12:49:30,019 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:49:30,037 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 80
# [MainThread] - 2025-07-14 12:49:41,885 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:49:41,911 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 81
# [MainThread] - 2025-07-14 12:49:53,719 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:49:53,741 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 82
# [MainThread] - 2025-07-14 12:50:05,454 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:50:05,480 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 83
# [MainThread] - 2025-07-14 12:50:17,249 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:50:17,268 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 84
# [MainThread] - 2025-07-14 12:50:29,127 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:50:29,145 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 85
# [MainThread] - 2025-07-14 12:50:40,892 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:50:40,918 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 86
# [MainThread] - 2025-07-14 12:50:52,659 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:50:52,681 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 87
# [MainThread] - 2025-07-14 12:51:04,456 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:51:04,475 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 88
# [MainThread] - 2025-07-14 12:51:16,229 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:51:16,248 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 89
# [MainThread] - 2025-07-14 12:51:27,993 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:51:28,012 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 90
# [MainThread] - 2025-07-14 12:51:39,733 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:51:39,752 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 91
# [MainThread] - 2025-07-14 12:51:51,479 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:51:51,500 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 92
# [MainThread] - 2025-07-14 12:52:03,282 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:52:03,305 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 93
# [MainThread] - 2025-07-14 12:52:15,109 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:52:15,130 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 94
# [MainThread] - 2025-07-14 12:52:26,853 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:52:26,876 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 95
# [MainThread] - 2025-07-14 12:52:38,613 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:52:38,637 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 96
# [MainThread] - 2025-07-14 12:52:50,561 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:52:50,585 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 97
# [MainThread] - 2025-07-14 12:53:02,507 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:53:02,531 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 98
# [MainThread] - 2025-07-14 12:53:14,320 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:53:14,340 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: 99
# [MainThread] - 2025-07-14 12:53:26,152 - INFO - [ir_para_proxima_pagina] - Navegando para a próxima página de resultados.
# [MainThread] - 2025-07-14 12:53:26,177 - INFO - [processar_ano_em_paralelo] - Coletando links da página de resultados: